# %%
import wrangle

import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns
import env

# DBSCAN import
from sklearn.cluster import DBSCAN

# Scaler import
from sklearn.preprocessing import MinMaxScaler

# %%
df = wrangle.prep_logs()

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False
# 2018-01-26 09:56:02   Full-Stack PHP     False
# 2018-01-26 09:56:05   Full-Stack PHP     False
# 2018-01-26 09:56:06   Full-Stack PHP     False
# 2018-01-26 09:56:24  Full-Stack Java     False

# %%
df.path.value_counts()
# Out:
# /                                                                50313
# search/search_index.json                                         19519
# javascript-i                                                     18983
# toc                                                              18297
# java-iii                                                         13733
#                                                                  ...
# 11-distributed-ml/6.3-prepare-part-3                                 1
# 10-anomaly-detection/2-continuous-probabilistic-methods.ipynb        1
# appendix/css-practice                                                1
# Clustering_DataPrep                                                  1
# Python_Libraries                                                     1
# Name: path, Length: 2313, dtype: int64

# %%
df.groupby(['path', 'name']).program.sum()
# Out:
# path                              name
# %20https://github.com/RaulCPena   Curie                                             Data Science
# '                                 Staff                                          Full-Stack Java
# ,%20https://github.com/RaulCPena  Curie                                             Data Science
# .git                              Voyageurs                                      Full-Stack Java
# .gitignore                        Darden                                            Data Science
#                                                                      ...
# where                             Florence                                          Data Science
# working-with-time-series-data     Darden       Data ScienceData ScienceData ScienceData Scien...
#                                   Staff                                          Full-Stack Java
# wp-admin                          Teddy                                          Full-Stack Java
# wp-login                          Teddy                                          Full-Stack Java
# Name: program, Length: 13565, dtype: object

# %% [markdown]
# ## 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
df[df.name != 'Staff']
# Out:
#                                                       path  user_id  \
# date_time
# 2018-01-26 09:55:03                                      /        1
# 2018-01-26 09:56:02                                java-ii        1
# 2018-01-26 09:56:05    java-ii/object-oriented-programming        1
# 2018-01-26 09:56:06     slides/object_oriented_programming        1
# 2018-01-26 09:56:24              javascript-i/conditionals        2
# ...                                                    ...      ...
# 2021-04-21 16:36:09                   jquery/personal-site      869
# 2021-04-21 16:36:34  html-css/css-ii/bootstrap-grid-system      948
# 2021-04-21 16:37:48                               java-iii      834
# 2021-04-21 16:38:14                      java-iii/servlets      834
# 2021-04-21 16:41:51           javascript-i/bom-and-dom/dom      875
#
#                      cohort_id              ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03        8.0    97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02        8.0    97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05        8.0    97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06        8.0    97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24       22.0    97.105.19.61    Teddy 2018-01-08 2018-05-17
# ...                        ...             ...      ...        ...        ...
# 2021-04-21 16:36:09      135.0    136.50.98.51    Marco 2021-01-25 2021-07-19
# 2021-04-21 16:36:34      138.0  104.48.214.211  Neptune 2021-03-15 2021-09-03
# 2021-04-21 16:37:48      134.0     67.11.50.23     Luna 2020-12-07 2021-06-08
# 2021-04-21 16:38:14      134.0     67.11.50.23     Luna 2020-12-07 2021-06-08
# 2021-04-21 16:41:51      135.0  24.242.150.231    Marco 2021-01-25 2021-07-19
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
# ...                                 ...                 ...         ...
# 2021-04-21 16:36:09 2021-01-20 21:31:11 2021-01-20 21:31:11         2.0
# 2021-04-21 16:36:34 2021-03-15 19:57:09 2021-03-15 19:57:09         2.0
# 2021-04-21 16:37:48 2020-12-07 16:58:43 2020-12-07 16:58:43         2.0
# 2021-04-21 16:38:14 2020-12-07 16:58:43 2020-12-07 16:58:43         2.0
# 2021-04-21 16:41:51 2021-01-20 21:31:11 2021-01-20 21:31:11         2.0
#
#                              program  is_staff
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False
# 2018-01-26 09:56:02   Full-Stack PHP     False
# 2018-01-26 09:56:05   Full-Stack PHP     False
# 2018-01-26 09:56:06   Full-Stack PHP     False
# 2018-01-26 09:56:24  Full-Stack Java     False
# ...                              ...       ...
# 2021-04-21 16:36:09  Full-Stack Java     False
# 2021-04-21 16:36:34  Full-Stack Java     False
# 2021-04-21 16:37:48  Full-Stack Java     False
# 2021-04-21 16:38:14  Full-Stack Java     False
# 2021-04-21 16:41:51  Full-Stack Java     False
#
# [816192 rows x 12 columns]

# %%
df.program.value_counts()
# Out:
# Full-Stack Java    713365
# Data Science       103412
# Full-Stack PHP      30548
# Front-End               5
# Name: program, dtype: int64

# %%
df[df.index > df.end_date].name.value_counts()
# Out:
# Staff         84031
# Lassen         9587
# Arches         8890
# Deimos         8089
# Teddy          5646
# Sequoia        5266
# Xanadu         5241
# Ceres          4964
# Olympic        4954
# Apex           4927
# Bayes          4725
# Ulysses        4446
# Ganymede       4406
# Zion           4254
# Andromeda      4245
# Curie          3638
# Fortuna        3505
# Betelgeuse     3420
# Voyageurs      3299
# Darden         3181
# Kings          2845
# Europa         2331
# Pinnacles      2158
# Hampton        1712
# Wrangell       1527
# Yosemite       1488
# Hyperion       1342
# Bash           1342
# Quincy         1237
# Niagara         755
# Mammoth         691
# Jupiter         662
# Glacier         598
# Joshua          302
# Ike             253
# Badlands         93
# Franklin         72
# Apollo            5
# Denali            4
# Everglades        1
# Name: name, dtype: int64

# %%
def one_program_df_prep(df, program_name):
    '''
    This function returns a dataframe consisting of data for only a single defined user
    '''
    df = df[df.program == program_name]
    df = df[df.name != 'Staff']
    #df.index = pd.to_datetime(df.date)
    #df = df.set_index(df.date)
    pages_one_program = df['path'].resample('d').count()
    return pages_one_program

# %%
def compute_pct_b(pages_one_program, span, weight, program_name):
    '''
    This function adds the %b of a bollinger band range for the page views of a single user's log activity
    '''
    # Calculate upper and lower bollinger band
    midband = pages_one_program.ewm(span=span).mean()
    stdev = pages_one_program.ewm(span=span).std()
    ub = midband + stdev*weight
    lb = midband - stdev*weight
    
    # Add upper and lower band values to dataframe
    bb = pd.concat([ub, lb], axis=1)
    
    # Combine all data into a single dataframe
    my_df = pd.concat([pages_one_program, midband, bb], axis=1)
    my_df.columns = ['pages_one_program', 'midband', 'ub', 'lb']
    
    # Calculate percent b and relevant user id to dataframe
    my_df['pct_b'] = (my_df['pages_one_program'] - my_df['lb'])/(my_df['ub'] - my_df['lb'])
    my_df['program'] = program_name
    return my_df

# %%
def plot_bands(my_df, program):
    '''
    This function plots the bolliger bands of the page views for a single user
    '''
    fig, ax = plt.subplots(figsize=(12,8))
    ax.plot(my_df.index, my_df.pages_one_program, label='Number of Pages, Progarm: '+str(program))
    ax.plot(my_df.index, my_df.midband, label = 'EMA/midband')
    ax.plot(my_df.index, my_df.ub, label = 'Upper Band')
    ax.plot(my_df.index, my_df.lb, label = 'Lower Band')
    ax.legend(loc='best')
    ax.set_ylabel('Number of Pages')
    plt.show()

# %%
def find_anomalies(df, program, span, weight, plot=False):
    '''
    This function returns the records where a user's daily activity exceeded the upper limit of a bollinger band range
    '''
    
    # Reduce dataframe to represent a single user
    pages_one_program = one_program_df_prep(df, program)
    
    # Add bollinger band data to dataframe
    my_df = compute_pct_b(pages_one_program, span, weight, program)
    
    # Plot data if requested (plot=True)
    if plot:
        plot_bands(my_df, program)
    
    # Return only records that sit outside of bollinger band upper limit
    return my_df[my_df.pct_b>1]

# %%
program = 'Data Science'
span = 30
weight = 3.5

# %%
user_df = find_anomalies(df, program, span, weight)

anomalies = pd.DataFrame()
user_df = find_anomalies(df, program, span, weight)
#anomalies = pd.concat([anomalies, user_df], axis=0)

# %%
anomalies = pd.DataFrame()
for u in list(df.program.unique()):
    user_df = find_anomalies(df, u, span, weight)
    anomalies = pd.concat([anomalies, user_df], axis=0)

# %%
anomalies
# Out:
#             pages_one_program   midband         ub         lb     pct_b  \
# date_time
# 2020-05-15                 79  6.945383  76.234598 -62.343833  1.019956
# 2020-08-02                 72  6.157982  71.876593 -59.560629  1.000939
# 2020-11-05                 44  3.100158  41.619692 -35.419376  1.030897
#
#                    program
# date_time
# 2020-05-15  Full-Stack PHP
# 2020-08-02  Full-Stack PHP
# 2020-11-05  Full-Stack PHP

# %%
anomalies.sort_values(by='pct_b', ascending=False)
# Out:
#             pages_one_program   midband         ub         lb     pct_b  \
# date_time
# 2020-11-05                 44  3.100158  41.619692 -35.419376  1.030897
# 2020-05-15                 79  6.945383  76.234598 -62.343833  1.019956
# 2020-08-02                 72  6.157982  71.876593 -59.560629  1.000939
#
#                    program
# date_time
# 2020-11-05  Full-Stack PHP
# 2020-05-15  Full-Stack PHP
# 2020-08-02  Full-Stack PHP

# %%
df_php = one_program_df_prep(df, 'Full-Stack PHP')

# %%
df_php.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %%
df_java = one_program_df_prep(df, 'Full-Stack Java')

# %%
df_java.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %%
df_data = one_program_df_prep(df, 'Data Science')

# %%
df_data.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %%
df_front = one_program_df_prep(df, 'Front-End')

# %%
df_front.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %% [markdown]
# Who is accessing the curriculum a lot (total views) and possibiliy looking at lot of unique pages (scraping?)
#
# Aggregate and compute 2 features...number of unique pages and total page views.

# %%
page_views = df[df.name != 'Staff'].groupby(['program', 'name'])['path'].agg(['count', 'nunique'])
page_views
# Out:
#                             count  nunique
# program         name
# Data Science    Bayes       26538      533
#                 Curie       21581      418
#                 Darden      32015      420
#                 Easley      14715      230
#                 Florence     8562      162
# Front-End       Apollo          5        4
# Full-Stack Java Andromeda   25359      366
#                 Apex        33568      273
#                 Bash        17713      275
#                 Betelgeuse  29356      334
#                 Ceres       40730      301
#                 Deimos      32888      288
#                 Europa      28033      267
#                 Fortuna     36902      258
#                 Ganymede    33844      296
#                 Hyperion    29855      270
#                 Jupiter     37109      288
#                 Kalypso     23691      273
#                 Luna        16623      239
#                 Mammoth       691      232
#                 Marco       16397      248
#                 Neptune      7276      136
#                 Niagara       755      135
#                 Oberon       1672       48
#                 Pinnacles    2158      325
#                 Sequoia      7444      312
#                 Teddy       30926      544
#                 Ulysses     28534      406
#                 Voyageurs   35636      377
#                 Wrangell    25586      421
#                 Xanadu      27749      283
#                 Yosemite    20743      314
#                 Zion        38096      317
# Full-Stack PHP  Arches       8890      342
#                 Badlands       93       44
#                 Denali          4        4
#                 Everglades      1        1
#                 Franklin       72       45
#                 Glacier       598      143
#                 Hampton      1712      278
#                 Ike           253       95
#                 Joshua        302      117
#                 Kings        2845      348
#                 Lassen       9587      486
#                 Olympic      4954      383
#                 Quincy       1237      282

# %% [markdown]
# # Now lets look at the cohorts specifically

# %%
def one_program__cohort_df_prep(df, program_name, cohort):
    '''
    This function returns a dataframe consisting of data for only a single defined user
    '''
    df = df[df.program == program_name]
    df = df[df.name != 'Staff']
    df = df[df.name == cohort]
    #df.index = pd.to_datetime(df.date)
    #df = df.set_index(df.date)
    pages_one_program_cohort = df['path'].resample('d').count()
    return pages_one_program_cohort

# %%
df_data_max = one_program__cohort_df_prep(df, 'Data Science', 'Darden')

# %%
df_data_max.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %%
df_java_max = one_program__cohort_df_prep(df, 'Full-Stack Java', 'Ceres')

# %%
df_java_max.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %%
df_php_max = one_program__cohort_df_prep(df, 'Full-Stack PHP', 'Lassen')

# %%
df_php_max.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %% [markdown]
# # Lets look at the biggest classes for a few of the cohorts

# %%
df_darden = df[df.name == 'Darden']

# %%
df_darden[df_darden.path != '/'].path.value_counts().idxmax()
# Out:
# 'classification/overview'

# %%
def one_program__cohort_df_prep(df, program_name, cohort):
    '''
    This function returns a dataframe consisting of data for only a single defined user
    '''
    df = df[df['name'].notna()]
    df = df[df.program == program_name]
    df = df[df.name != 'Staff']
    df = df[df.name != 'Everglades']
    df = df[df.name == cohort]
    df = df[df.path != '/']
    #df.index = pd.to_datetime(df.date)
    #df = df.set_index(df.date)
    pages_one_program_cohort = df['path'].resample('d').count()
    return pages_one_program_cohort

# %%
def biggest_lesson(df, cohort):
    df = df[df.name == cohort]
    df = df[df.path != '/']
    df = df.dropna()
    df_bigget_lesson = df.path.value_counts().idxmax()
    return df_bigget_lesson

# %%
for i in list(df[df.name != 'Staff'].name.unique()):
    big_lesson = biggest_lesson(df, i)
    print(big_lesson, ' :', i, '  :', df.program)
# Out:
# java-iii  : Hampton   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# spring  : Teddy   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# spring  : Sequoia   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# javascript-i  : Arches   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# spring  : Niagara   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# javascript-i  : Pinnacles   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# content/laravel/intro  : Quincy   : date_time
# 2018-01-26 09:55:03     Full-Stack PHP
# 2018-01-26 09:56:02     Full-Stack PHP
# 2018-01-26 09:56:05     Full-Stack PHP
# 2018-01-26 09:56:06     Full-Stack PHP
# 2018-01-26 09:56:24    Full-Stack Java
#                             ...
# 2021-04-21 16:41:51    Full-Stack Java
# 2021-04-21 16:42:02    Full-Stack Java
# 2021-04-21 16:42:09    Full-Stack Java
# 2021-04-21 16:44:37    Full-Stack Java
# 2021-04-21 16:44:39    Full-Stack Java
# Name: program, Length: 900223, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-387-3722a3d5dd93> in <module>
#       1 for i in list(df[df.name != 'Staff'].name.unique()):
# ----> 2     big_lesson = biggest_lesson(df, i)
#       3     print(big_lesson, ' :', i, '  :', df.program)
#
# <ipython-input-376-d6bd45cd2dca> in biggest_lesson(df_new, cohort)
#      10     df_new = df_new.dropna()
#      11     #df_new = df_new[df_new.name != 'Everglades']
# ---> 12     df_bigget_lesson = df_new.path.value_counts().idxmax()
#      13     return df_bigget_lesson
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2172         """
#    2173         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2174         i = nanops.nanargmax(self._values, skipna=skipna)
#    2175         if i == -1:
#    2176             return np.nan
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      71             try:
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#      75                 # we want to transform an object array
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanargmax(values, axis, skipna, mask)
#    1027     """
#    1028     values, mask, _, _, _ = _get_values(values, True, fill_value_typ="-inf", mask=mask)
# -> 1029     result = values.argmax(axis)
#    1030     result = _maybe_arg_null_out(result, axis, mask, skipna)
#    1031     return result
#
# ValueError: attempt to get argmax of an empty sequence

# %%
#Front-End
something = biggest_lesson(df, 'Apollo')
something
# Out:
# 'content/html-css'

# %%
df[df.name != 'nan'].name.unique()
# Out:
# array(['Hampton', 'Teddy', 'Sequoia', 'Arches', 'Niagara', 'Pinnacles',
#        'Quincy', nan, 'Kings', 'Lassen', 'Mammoth', 'Glacier', 'Denali',
#        'Joshua', 'Olympic', 'Ulysses', 'Badlands', 'Apollo', 'Ike',
#        'Voyageurs', 'Wrangell', 'Xanadu', 'Franklin', 'Yosemite', 'Staff',
#        'Zion', 'Andromeda', 'Betelgeuse', 'Ceres', 'Bayes', 'Deimos',
#        'Europa', 'Fortuna', 'Curie', 'Apex', 'Ganymede', 'Everglades',
#        'Hyperion', 'Darden', 'Bash', 'Jupiter', 'Kalypso', 'Luna',
#        'Easley', 'Marco', 'Neptune', 'Florence', 'Oberon'], dtype=object)

# %%
df_new = df[df['name'].notna()]
df_new = df_new[df_new.name != 'Everglades']

# %%
df_new.isna().sum()
# Out:
# path          1
# user_id       0
# cohort_id     0
# ip            0
# name          0
# start_date    0
# end_date      0
# created_at    0
# updated_at    0
# program_id    0
# program       0
# is_staff      0
# dtype: int64

# %%
df.shape
# Out:
# (900223, 12)

# %%
df_new.shape
# Out:
# (847329, 12)

# %%
df_new.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False
# 2018-01-26 09:56:02   Full-Stack PHP     False
# 2018-01-26 09:56:05   Full-Stack PHP     False
# 2018-01-26 09:56:06   Full-Stack PHP     False
# 2018-01-26 09:56:24  Full-Stack Java     False

# %%
### Finding the largest lesson

# %%
def biggest_lesson(df_new, cohort):
    df_new = df_new[df_new.name == cohort]
    df_new = df_new[df_new.path != '/']
    df_new = df_new[df_new.path != 'mkdocs/search_index.json']
    df_new = df_new[df_new.path != 'search/search_index.json']
    df_new = df_new[df_new.path != 'toc']
    df_new = df_new[df_new.path != 'index.html']
    df_new = df_new[df_new.path != 'fundamentals/modern-data-scientist.jpg']
    df_new = df_new[df_new.path != 'fundamentals/AI-ML-DL-timeline.jpg']
    df_new = df_new.dropna()
    #df_new = df_new[df_new.name != 'Everglades']
    df_bigget_lesson = df_new.path.value_counts().idxmax()
    return df_bigget_lesson

# %%
df_new[df_new.name != 'Staff'].name.unique()
# Out:
# array(['Hampton', 'Teddy', 'Sequoia', 'Arches', 'Niagara', 'Pinnacles',
#        'Quincy', 'Kings', 'Lassen', 'Mammoth', 'Glacier', 'Denali',
#        'Joshua', 'Olympic', 'Ulysses', 'Badlands', 'Apollo', 'Ike',
#        'Voyageurs', 'Wrangell', 'Xanadu', 'Franklin', 'Yosemite', 'Zion',
#        'Andromeda', 'Betelgeuse', 'Ceres', 'Bayes', 'Deimos', 'Europa',
#        'Fortuna', 'Curie', 'Apex', 'Ganymede', 'Hyperion', 'Darden',
#        'Bash', 'Jupiter', 'Kalypso', 'Luna', 'Easley', 'Marco', 'Neptune',
#        'Florence', 'Oberon'], dtype=object)

# %% [markdown]
# # This answe4rs the question

# %%
df_lessons = pd.DataFrame()
programs_list = []
lesson_list = []
cohort_list = []

# %%
for i in list(df_new[df_new.name != 'Staff'].name.unique()):
    big_lesson = biggest_lesson(df_new, i)
    print(big_lesson, ' :', i, ' :' ,df_new[df_new.name == i].program.unique())
    print('-----------------------------------')
    programs_list.extend(df_new[df_new.name == i].program.unique())
    lesson_list.append(big_lesson)
    cohort_list.append(i)
# Out:
# java-iii  : Hampton  : ['Full-Stack PHP']
# -----------------------------------
# spring  : Teddy  : ['Full-Stack Java']
# -----------------------------------
# spring  : Sequoia  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Arches  : ['Full-Stack PHP']
# -----------------------------------
# spring  : Niagara  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Pinnacles  : ['Full-Stack Java']
# -----------------------------------
# content/laravel/intro  : Quincy  : ['Full-Stack PHP']
# -----------------------------------
# content/laravel/intro  : Kings  : ['Full-Stack PHP']
# -----------------------------------
# javascript-i  : Lassen  : ['Full-Stack PHP']
# -----------------------------------
# java-i  : Mammoth  : ['Full-Stack Java']
# -----------------------------------
# content/html-css  : Glacier  : ['Full-Stack PHP']
# -----------------------------------
# prework/versioning/github  : Denali  : ['Full-Stack PHP']
# -----------------------------------
# content/html-css  : Joshua  : ['Full-Stack PHP']
# -----------------------------------
# javascript-i  : Olympic  : ['Full-Stack PHP']
# -----------------------------------
# html-css  : Ulysses  : ['Full-Stack Java']
# -----------------------------------
# content/php_ii/command-line  : Badlands  : ['Full-Stack PHP']
# -----------------------------------
# content/html-css  : Apollo  : ['Front-End']
# -----------------------------------
# html-css  : Ike  : ['Full-Stack PHP']
# -----------------------------------
# javascript-i  : Voyageurs  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Wrangell  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Xanadu  : ['Full-Stack Java']
# -----------------------------------
# javascript-ii/es6  : Franklin  : ['Full-Stack PHP']
# -----------------------------------
# javascript-i  : Yosemite  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Zion  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Andromeda  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Betelgeuse  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Ceres  : ['Full-Stack Java']
# -----------------------------------
# 1-fundamentals/modern-data-scientist.jpg  : Bayes  : ['Data Science']
# -----------------------------------
# javascript-i  : Deimos  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Europa  : ['Full-Stack Java']
# -----------------------------------
# java-iii  : Fortuna  : ['Full-Stack Java']
# -----------------------------------
# 6-regression/1-overview  : Curie  : ['Data Science']
# -----------------------------------
# html-css  : Apex  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Ganymede  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Hyperion  : ['Full-Stack Java']
# -----------------------------------
# classification/overview  : Darden  : ['Data Science']
# -----------------------------------
# javascript-i  : Bash  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Jupiter  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Kalypso  : ['Full-Stack Java']
# -----------------------------------
# javascript-i  : Luna  : ['Full-Stack Java']
# -----------------------------------
# classification/scale_features_or_not.svg  : Easley  : ['Data Science']
# -----------------------------------
# javascript-i  : Marco  : ['Full-Stack Java']
# -----------------------------------
# javascript-i/introduction/working-with-data-types-operators-and-variables  : Neptune  : ['Full-Stack Java']
# -----------------------------------
# fundamentals/intro-to-data-science  : Florence  : ['Data Science']
# -----------------------------------
# javascript-i/introduction/operators  : Oberon  : ['Full-Stack Java']
# -----------------------------------

# %%
df_lessons = pd.DataFrame(
    {'Lesson': lesson_list,
     'Cohort': cohort_list,
     'Program': programs_list
    })

df_lessons.head()
# Out:
#          Lesson   Cohort          Program
# 0      java-iii  Hampton   Full-Stack PHP
# 1        spring    Teddy  Full-Stack Java
# 2        spring  Sequoia  Full-Stack Java
# 3  javascript-i   Arches   Full-Stack PHP
# 4        spring  Niagara  Full-Stack Java

# %% [markdown]
# # Answer Answer

# %%
df_lessons.groupby(['Program', 'Cohort']).Lesson.max()
# Out:
# Program          Cohort
# Data Science     Bayes                  1-fundamentals/modern-data-scientist.jpg
#                  Curie                                   6-regression/1-overview
#                  Darden                                  classification/overview
#                  Easley                 classification/scale_features_or_not.svg
#                  Florence                     fundamentals/intro-to-data-science
# Front-End        Apollo                                         content/html-css
# Full-Stack Java  Andromeda                                          javascript-i
#                  Apex                                                   html-css
#                  Bash                                               javascript-i
#                  Betelgeuse                                         javascript-i
#                  Ceres                                              javascript-i
#                  Deimos                                             javascript-i
#                  Europa                                             javascript-i
#                  Fortuna                                                java-iii
#                  Ganymede                                           javascript-i
#                  Hyperion                                           javascript-i
#                  Jupiter                                            javascript-i
#                  Kalypso                                            javascript-i
#                  Luna                                               javascript-i
#                  Mammoth                                                  java-i
#                  Marco                                              javascript-i
#                  Neptune       javascript-i/introduction/working-with-data-ty...
#                  Niagara                                                  spring
#                  Oberon                      javascript-i/introduction/operators
#                  Pinnacles                                          javascript-i
#                  Sequoia                                                  spring
#                  Teddy                                                    spring
#                  Ulysses                                                html-css
#                  Voyageurs                                          javascript-i
#                  Wrangell                                           javascript-i
#                  Xanadu                                             javascript-i
#                  Yosemite                                           javascript-i
#                  Zion                                               javascript-i
# Full-Stack PHP   Arches                                             javascript-i
#                  Badlands                            content/php_ii/command-line
#                  Denali                                prework/versioning/github
#                  Franklin                                      javascript-ii/es6
#                  Glacier                                        content/html-css
#                  Hampton                                                java-iii
#                  Ike                                                    html-css
#                  Joshua                                         content/html-css
#                  Kings                                     content/laravel/intro
#                  Lassen                                             javascript-i
#                  Olympic                                            javascript-i
#                  Quincy                                    content/laravel/intro
# Name: Lesson, dtype: object

# %%
df_lessons.groupby('Program').Lesson.max()
# Out:
# Program
# Data Science       fundamentals/intro-to-data-science
# Front-End                            content/html-css
# Full-Stack Java                                spring
# Full-Stack PHP              prework/versioning/github
# Name: Lesson, dtype: object

# %%
def one_program__cohort_df_prep(df, program_name, cohort):
    '''
    This function returns a dataframe consisting of data for only a single defined user
    '''
    df = df[df['name'].notna()]
    df = df[df.program == program_name]
    df = df[df.name != 'Staff']
    df = df[df.name != 'Everglades']
    df = df[df.name == cohort]
    df = df[df.path != '/']
    #df.index = pd.to_datetime(df.date)
    #df = df.set_index(df.date)
    pages_one_program_cohort = df['path'].resample('d').count()
    return pages_one_program_cohort

# %% [markdown]
# # Lets look at dbscan of some unique paths

# %%
page_views = df_new[df_new.name != 'Staff'].groupby(['program', 'name'])['path'].agg(['count', 'nunique'])
page_views
# Out:
#                             count  nunique
# program         name
# Data Science    Bayes       26538      533
#                 Curie       21581      418
#                 Darden      32015      420
#                 Easley      14715      230
#                 Florence     8562      162
# Front-End       Apollo          5        4
# Full-Stack Java Andromeda   25359      366
#                 Apex        33568      273
#                 Bash        17713      275
#                 Betelgeuse  29356      334
#                 Ceres       40730      301
#                 Deimos      32888      288
#                 Europa      28033      267
#                 Fortuna     36902      258
#                 Ganymede    33844      296
#                 Hyperion    29855      270
#                 Jupiter     37109      288
#                 Kalypso     23691      273
#                 Luna        16623      239
#                 Mammoth       691      232
#                 Marco       16397      248
#                 Neptune      7276      136
#                 Niagara       755      135
#                 Oberon       1672       48
#                 Pinnacles    2158      325
#                 Sequoia      7444      312
#                 Teddy       30926      544
#                 Ulysses     28534      406
#                 Voyageurs   35636      377
#                 Wrangell    25586      421
#                 Xanadu      27749      283
#                 Yosemite    20743      314
#                 Zion        38096      317
# Full-Stack PHP  Arches       8890      342
#                 Badlands       93       44
#                 Denali          4        4
#                 Franklin       72       45
#                 Glacier       598      143
#                 Hampton      1712      278
#                 Ike           253       95
#                 Joshua        302      117
#                 Kings        2845      348
#                 Lassen       9587      486
#                 Olympic      4954      383
#                 Quincy       1237      282

# %%
# create the scaler
scaler = MinMaxScaler().fit(page_views)
# use the scaler
page_views_scaled_array = scaler.transform(page_views)
page_views_scaled_array[0:10]
# Out:
# array([[6.51524824e-01, 9.79629630e-01],
#        [5.29808967e-01, 7.66666667e-01],
#        [7.86008938e-01, 7.70370370e-01],
#        [3.61218877e-01, 4.18518519e-01],
#        [2.10136031e-01, 2.92592593e-01],
#        [2.45543388e-05, 0.00000000e+00],
#        [6.22575259e-01, 6.70370370e-01],
#        [8.24141826e-01, 4.98148148e-01],
#        [4.34832785e-01, 5.01851852e-01],
#        [7.20718951e-01, 6.11111111e-01]])

# %%
dbsc = DBSCAN(eps = 0.1, min_samples=4).fit(page_views_scaled_array)
print(dbsc)
# Out:
# DBSCAN(eps=0.1, min_samples=4)

# %%
# Now, let's add the scaled value columns back onto the dataframe

columns = list(page_views.columns)
scaled_columns = ["scaled_" + column for column in columns]
scaled_columns
# Out:
# ['scaled_count', 'scaled_nunique']

# %%
# Create a dataframe containing the scaled values
scaled_df = pd.DataFrame(page_views_scaled_array, columns=scaled_columns, index=page_views.index)
scaled_df.head()
# Out:
#                        scaled_count  scaled_nunique
# program      name
# Data Science Bayes         0.651525        0.979630
#              Curie         0.529809        0.766667
#              Darden        0.786009        0.770370
#              Easley        0.361219        0.418519
#              Florence      0.210136        0.292593

# %%
# Merge the scaled and non-scaled values into one dataframe
page_views = page_views.merge(scaled_df, left_index=True, right_index=True)
page_views
# Out:
#                             count  nunique  scaled_count  scaled_nunique
# program         name
# Data Science    Bayes       26538      533      0.651525        0.979630
#                 Curie       21581      418      0.529809        0.766667
#                 Darden      32015      420      0.786009        0.770370
#                 Easley      14715      230      0.361219        0.418519
#                 Florence     8562      162      0.210136        0.292593
# Front-End       Apollo          5        4      0.000025        0.000000
# Full-Stack Java Andromeda   25359      366      0.622575        0.670370
#                 Apex        33568      273      0.824142        0.498148
#                 Bash        17713      275      0.434833        0.501852
#                 Betelgeuse  29356      334      0.720719        0.611111
#                 Ceres       40730      301      1.000000        0.550000
#                 Deimos      32888      288      0.807445        0.525926
#                 Europa      28033      267      0.688234        0.487037
#                 Fortuna     36902      258      0.906006        0.470370
#                 Ganymede    33844      296      0.830919        0.540741
#                 Hyperion    29855      270      0.732972        0.492593
#                 Jupiter     37109      288      0.911089        0.525926
#                 Kalypso     23691      273      0.581619        0.498148
#                 Luna        16623      239      0.408069        0.435185
#                 Mammoth       691      232      0.016869        0.422222
#                 Marco       16397      248      0.402519        0.451852
#                 Neptune      7276      136      0.178559        0.244444
#                 Niagara       755      135      0.018440        0.242593
#                 Oberon       1672       48      0.040957        0.081481
#                 Pinnacles    2158      325      0.052890        0.594444
#                 Sequoia      7444      312      0.182684        0.570370
#                 Teddy       30926      544      0.759269        1.000000
#                 Ulysses     28534      406      0.700535        0.744444
#                 Voyageurs   35636      377      0.874920        0.690741
#                 Wrangell    25586      421      0.628149        0.772222
#                 Xanadu      27749      283      0.681260        0.516667
#                 Yosemite    20743      314      0.509232        0.574074
#                 Zion        38096      317      0.935324        0.579630
# Full-Stack PHP  Arches       8890      342      0.218190        0.625926
#                 Badlands       93       44      0.002185        0.074074
#                 Denali          4        4      0.000000        0.000000
#                 Franklin       72       45      0.001670        0.075926
#                 Glacier       598      143      0.014585        0.257407
#                 Hampton      1712      278      0.041939        0.507407
#                 Ike           253       95      0.006114        0.168519
#                 Joshua        302      117      0.007317        0.209259
#                 Kings        2845      348      0.069759        0.637037
#                 Lassen       9587      486      0.235304        0.892593
#                 Olympic      4954      383      0.121544        0.701852
#                 Quincy       1237      282      0.030275        0.514815

# %%
labels = dbsc.labels_
labels[0:15]
# Out:
# array([-1, -1, -1,  2, -1,  0, -1,  1,  2, -1,  1,  1,  1,  1,  1])

# %%
#add labels back to the dataframe
page_views['labels'] = labels

# how many unique labels (clusters) are created by DBSCAN?
page_views.labels.value_counts()
# Out:
# -1    17
#  1    10
#  0     9
#  3     5
#  2     4
# Name: labels, dtype: int64

# %%
page_views[page_views.labels==3]
# Out:
#                            count  nunique  scaled_count  scaled_nunique  \
# program         name
# Full-Stack Java Mammoth      691      232      0.016869        0.422222
#                 Pinnacles   2158      325      0.052890        0.594444
# Full-Stack PHP  Hampton     1712      278      0.041939        0.507407
#                 Kings       2845      348      0.069759        0.637037
#                 Quincy      1237      282      0.030275        0.514815
#
#                            labels
# program         name
# Full-Stack Java Mammoth         3
#                 Pinnacles       3
# Full-Stack PHP  Hampton         3
#                 Kings           3
#                 Quincy          3

# %%
page_views[page_views.labels==2]
# Out:
#                         count  nunique  scaled_count  scaled_nunique  labels
# program         name
# Data Science    Easley  14715      230      0.361219        0.418519       2
# Full-Stack Java Bash    17713      275      0.434833        0.501852       2
#                 Luna    16623      239      0.408069        0.435185       2
#                 Marco   16397      248      0.402519        0.451852       2

# %%
page_views[page_views.labels==1]
# Out:
#                           count  nunique  scaled_count  scaled_nunique  labels
# program         name
# Full-Stack Java Apex      33568      273      0.824142        0.498148       1
#                 Ceres     40730      301      1.000000        0.550000       1
#                 Deimos    32888      288      0.807445        0.525926       1
#                 Europa    28033      267      0.688234        0.487037       1
#                 Fortuna   36902      258      0.906006        0.470370       1
#                 Ganymede  33844      296      0.830919        0.540741       1
#                 Hyperion  29855      270      0.732972        0.492593       1
#                 Jupiter   37109      288      0.911089        0.525926       1
#                 Xanadu    27749      283      0.681260        0.516667       1
#                 Zion      38096      317      0.935324        0.579630       1

# %%
page_views[page_views.labels==0]
# Out:
#                           count  nunique  scaled_count  scaled_nunique  labels
# program         name
# Front-End       Apollo        5        4      0.000025        0.000000       0
# Full-Stack Java Niagara     755      135      0.018440        0.242593       0
#                 Oberon     1672       48      0.040957        0.081481       0
# Full-Stack PHP  Badlands     93       44      0.002185        0.074074       0
#                 Denali        4        4      0.000000        0.000000       0
#                 Franklin     72       45      0.001670        0.075926       0
#                 Glacier     598      143      0.014585        0.257407       0
#                 Ike         253       95      0.006114        0.168519       0
#                 Joshua      302      117      0.007317        0.209259       0

# %% [markdown]
# #### label '-1' represents observations which are not part of any cluster and are potential anomalies warranting further investigation

# %%
page_views[page_views.labels==-1]
# Out:
#                             count  nunique  scaled_count  scaled_nunique  \
# program         name
# Data Science    Bayes       26538      533      0.651525        0.979630
#                 Curie       21581      418      0.529809        0.766667
#                 Darden      32015      420      0.786009        0.770370
#                 Florence     8562      162      0.210136        0.292593
# Full-Stack Java Andromeda   25359      366      0.622575        0.670370
#                 Betelgeuse  29356      334      0.720719        0.611111
#                 Kalypso     23691      273      0.581619        0.498148
#                 Neptune      7276      136      0.178559        0.244444
#                 Sequoia      7444      312      0.182684        0.570370
#                 Teddy       30926      544      0.759269        1.000000
#                 Ulysses     28534      406      0.700535        0.744444
#                 Voyageurs   35636      377      0.874920        0.690741
#                 Wrangell    25586      421      0.628149        0.772222
#                 Yosemite    20743      314      0.509232        0.574074
# Full-Stack PHP  Arches       8890      342      0.218190        0.625926
#                 Lassen       9587      486      0.235304        0.892593
#                 Olympic      4954      383      0.121544        0.701852
#
#                             labels
# program         name
# Data Science    Bayes           -1
#                 Curie           -1
#                 Darden          -1
#                 Florence        -1
# Full-Stack Java Andromeda       -1
#                 Betelgeuse      -1
#                 Kalypso         -1
#                 Neptune         -1
#                 Sequoia         -1
#                 Teddy           -1
#                 Ulysses         -1
#                 Voyageurs       -1
#                 Wrangell        -1
#                 Yosemite        -1
# Full-Stack PHP  Arches          -1
#                 Lassen          -1
#                 Olympic         -1

# %%
plt.scatter(page_views['scaled_count'], page_views['scaled_nunique'], c=page_views.labels)
plt.show()

# %% [markdown]
# We will accomplish this by breaking down to the following tasks:
#
# 1) Make the analysis process (which we will discuss later) work over all users.
#
# 2) Turn the analysis process and calculations into a function that can be used to loop through for each user.
#
# 3) Test the function on a single user.
#
# 4) Analyze by looping over all users.
#
# ---------------------
# The analysis process will look like this, for each user:
#
# 1) Compute necessary metrics to arrive at the final metric, %b (percent-b).
#
# 2) Add user id to the dataframe that contains all the metrics, including %b.
#
# 3) Filter to rows where %b indicates anomaly (i.e. > 1)
#
# 4) Append rows of anomalies of new user to previous users' anomalous activity.

# %% [markdown]
# ## 3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?

# %%
# students == user_id
# active == ?
# curriculum access? low page count?
# info as in what cohorts? what programs specifically have a low access amount?

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False
# 2018-01-26 09:56:02   Full-Stack PHP     False
# 2018-01-26 09:56:05   Full-Stack PHP     False
# 2018-01-26 09:56:06   Full-Stack PHP     False
# 2018-01-26 09:56:24  Full-Stack Java     False

# %%
# active is times start_date between end_date == active
df['active'] = df.index < df.end_date

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff  active
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False   False
# 2018-01-26 09:56:02   Full-Stack PHP     False   False
# 2018-01-26 09:56:05   Full-Stack PHP     False   False
# 2018-01-26 09:56:06   Full-Stack PHP     False   False
# 2018-01-26 09:56:24  Full-Stack Java     False    True

# %%
# get only active dataframe
df_active = df[df.active == True]

# %%
df_active
# Out:
#                                                       path  user_id  \
# date_time
# 2018-01-26 09:56:24              javascript-i/conditionals        2
# 2018-01-26 09:56:41                     javascript-i/loops        2
# 2018-01-26 09:56:46              javascript-i/conditionals        3
# 2018-01-26 09:56:48                 javascript-i/functions        3
# 2018-01-26 09:56:59                     javascript-i/loops        2
# ...                                                    ...      ...
# 2021-04-21 16:36:09                   jquery/personal-site      869
# 2021-04-21 16:36:34  html-css/css-ii/bootstrap-grid-system      948
# 2021-04-21 16:37:48                               java-iii      834
# 2021-04-21 16:38:14                      java-iii/servlets      834
# 2021-04-21 16:41:51           javascript-i/bom-and-dom/dom      875
#
#                      cohort_id              ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:56:24       22.0    97.105.19.61    Teddy 2018-01-08 2018-05-17
# 2018-01-26 09:56:41       22.0    97.105.19.61    Teddy 2018-01-08 2018-05-17
# 2018-01-26 09:56:46       22.0    97.105.19.61    Teddy 2018-01-08 2018-05-17
# 2018-01-26 09:56:48       22.0    97.105.19.61    Teddy 2018-01-08 2018-05-17
# 2018-01-26 09:56:59       22.0    97.105.19.61    Teddy 2018-01-08 2018-05-17
# ...                        ...             ...      ...        ...        ...
# 2021-04-21 16:36:09      135.0    136.50.98.51    Marco 2021-01-25 2021-07-19
# 2021-04-21 16:36:34      138.0  104.48.214.211  Neptune 2021-03-15 2021-09-03
# 2021-04-21 16:37:48      134.0     67.11.50.23     Luna 2020-12-07 2021-06-08
# 2021-04-21 16:38:14      134.0     67.11.50.23     Luna 2020-12-07 2021-06-08
# 2021-04-21 16:41:51      135.0  24.242.150.231    Marco 2021-01-25 2021-07-19
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
# 2018-01-26 09:56:41 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
# 2018-01-26 09:56:46 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
# 2018-01-26 09:56:48 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
# 2018-01-26 09:56:59 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
# ...                                 ...                 ...         ...
# 2021-04-21 16:36:09 2021-01-20 21:31:11 2021-01-20 21:31:11         2.0
# 2021-04-21 16:36:34 2021-03-15 19:57:09 2021-03-15 19:57:09         2.0
# 2021-04-21 16:37:48 2020-12-07 16:58:43 2020-12-07 16:58:43         2.0
# 2021-04-21 16:38:14 2020-12-07 16:58:43 2020-12-07 16:58:43         2.0
# 2021-04-21 16:41:51 2021-01-20 21:31:11 2021-01-20 21:31:11         2.0
#
#                              program  is_staff  active
# date_time
# 2018-01-26 09:56:24  Full-Stack Java     False    True
# 2018-01-26 09:56:41  Full-Stack Java     False    True
# 2018-01-26 09:56:46  Full-Stack Java     False    True
# 2018-01-26 09:56:48  Full-Stack Java     False    True
# 2018-01-26 09:56:59  Full-Stack Java     False    True
# ...                              ...       ...     ...
# 2021-04-21 16:36:09  Full-Stack Java     False    True
# 2021-04-21 16:36:34  Full-Stack Java     False    True
# 2021-04-21 16:37:48  Full-Stack Java     False    True
# 2021-04-21 16:38:14  Full-Stack Java     False    True
# 2021-04-21 16:41:51  Full-Stack Java     False    True
#
# [647198 rows x 13 columns]

# %%
# curriculum access? low page count? (lower bound)
# info as in what cohorts? what programs specifically have a low access amount?

# %%
pages = df_active['path'].resample('d').count()
pages.head()
# Out:
# date_time
# 2018-01-26    496
# 2018-01-27    188
# 2018-01-28    145
# 2018-01-29    725
# 2018-01-30    488
# Freq: D, Name: path, dtype: int64

# %%
# set the window span
span = 30

# compute midband
midband = pages.ewm(span=span).mean()

midband.head()
# Out:
# date_time
# 2018-01-26    496.000000
# 2018-01-27    336.866667
# 2018-01-28    268.601629
# 2018-01-29    394.356012
# 2018-01-30    415.662286
# Freq: D, Name: path, dtype: float64

# %%
# compute exponential stdev
stdev = pages.ewm(span=span).std()

stdev.head()
# Out:
# date_time
# 2018-01-26           NaN
# 2018-01-27    217.788889
# 2018-01-28    188.681591
# 2018-01-29    280.137252
# 2018-01-30    242.455115
# Freq: D, Name: path, dtype: float64

# %%
# compute upper and lower bands
ub = midband + stdev*3
lb = midband - stdev*3
ub, lb
# Out:
# (date_time
#  2018-01-26            NaN
#  2018-01-27     990.233332
#  2018-01-28     834.646401
#  2018-01-29    1234.767767
#  2018-01-30    1143.027631
#                   ...
#  2021-04-17    2654.951328
#  2021-04-18    2610.586532
#  2021-04-19    2694.818748
#  2021-04-20    2708.799354
#  2021-04-21    2647.648123
#  Freq: D, Name: path, Length: 1182, dtype: float64,
#  date_time
#  2018-01-26           NaN
#  2018-01-27   -316.499999
#  2018-01-28   -297.443143
#  2018-01-29   -446.055743
#  2018-01-30   -311.703058
#                   ...
#  2021-04-17   -690.681583
#  2021-04-18   -710.721288
#  2021-04-19   -700.364164
#  2021-04-20   -652.567647
#  2021-04-21   -615.560397
#  Freq: D, Name: path, Length: 1182, dtype: float64)

# %%
# concatenate ub and lb together into one df, bb
bb = pd.concat([ub, lb], axis=1)

bb.columns = ['ub', 'lb']
bb.head()
# Out:
#                      ub          lb
# date_time
# 2018-01-26          NaN         NaN
# 2018-01-27   990.233332 -316.499999
# 2018-01-28   834.646401 -297.443143
# 2018-01-29  1234.767767 -446.055743
# 2018-01-30  1143.027631 -311.703058

# %%
my_df = pd.concat([pages, midband, bb], axis=1)
my_df.columns = ['pages', 'midband', 'ub', 'lb']
my_df.head()
# Out:
#             pages     midband           ub          lb
# date_time
# 2018-01-26    496  496.000000          NaN         NaN
# 2018-01-27    188  336.866667   990.233332 -316.499999
# 2018-01-28    145  268.601629   834.646401 -297.443143
# 2018-01-29    725  394.356012  1234.767767 -446.055743
# 2018-01-30    488  415.662286  1143.027631 -311.703058

# %%
fig, ax = plt.subplots(figsize=(12,8))

ax.plot(my_df.index, my_df.pages, label='Number of Pages')

ax.plot(my_df.index, my_df.midband, label = '30-day EMA/midband')
ax.plot(my_df.index, my_df.ub, label = 'Upper Band')
ax.plot(my_df.index, my_df.lb, label = 'Lower Band')

ax.legend(loc='best')
ax.set_ylabel('Number of pages')

plt.show()

# %%
def one_user_df_prep(df_active, user):
    '''
    This function returns a dataframe consisting of data for only a single defined user
    '''
    df_active = df_active[df_active.user_id == user]
    #df = df[df.program == program] #'data_science'
    #df_active.date = pd.to_datetime(df.date)
    #df_active = df_active.set_index(df.date)
    pages_one_user = df_active['path'].resample('d').count()
    return pages_one_user

def compute_pct_b(pages_one_user, span, weight, user):
    '''
    This function adds the %b of a bollinger band range for the page views of a single user's log activity
    '''
    # Calculate upper and lower bollinger band
    midband = pages_one_user.ewm(span=span).mean()
    stdev = pages_one_user.ewm(span=span).std()
    ub = midband + stdev*weight
    lb = midband - stdev*weight
    #program = pages_one_user[pages_one_user.user_id == user].program.unique()
    
    # Add upper and lower band values to dataframe
    bb = pd.concat([ub, lb], axis=1)
    
    # Combine all data into a single dataframe
    my_df = pd.concat([pages_one_user, midband, bb], axis=1)
    my_df.columns = ['pages_one_user', 'midband', 'ub', 'lb']
    
    # Calculate percent b and relevant user id to dataframe
    my_df['pct_b'] = (my_df['pages_one_user'] - my_df['lb'])/(my_df['ub'] - my_df['lb'])
    my_df['user_id'] = user
    #my_df['program'] = program
    return my_df

def plot_bands(my_df, user):
    '''
    This function plots the bolliger bands of the page views for a single user
    '''
    fig, ax = plt.subplots(figsize=(12,8))
    ax.plot(my_df.index, my_df.pages_one_user, label='Number of Pages, User: '+str(user))
    ax.plot(my_df.index, my_df.midband, label = 'EMA/midband')
    ax.plot(my_df.index, my_df.ub, label = 'Upper Band')
    ax.plot(my_df.index, my_df.lb, label = 'Lower Band')
    ax.legend(loc='best')
    ax.set_ylabel('Number of Pages')
    plt.show()

def find_anomalies(df_active, user, span, weight, plot=False):
    '''
    This function returns the records where a user's daily activity exceeded the upper limit of a bollinger band range
    '''
    
    # Reduce dataframe to represent a single user
    pages_one_user = one_user_df_prep(df_active, user)
    
    # Add bollinger band data to dataframe
    my_df = compute_pct_b(pages_one_user, span, weight, user)
    
    # Plot data if requested (plot=True)
    if plot:
        plot_bands(my_df, user)
    
    # Return only records that sit outside of bollinger band upper limit
    return my_df[my_df.pct_b>1]

# %%
# Lets look throughall usesr
span = 30
weight = 3.5

anomalies_active = pd.DataFrame()
for u in list(df_active.user_id.unique()):
    user_df = find_anomalies(df_active, u, span, weight)
    anomalies_active = pd.concat([anomalies_active, user_df], axis=0)

# %%
anomalies_active
# Out:
#             pages_one_user    midband          ub          lb     pct_b  \
# date_time
# 2020-01-13               6   0.387097    5.634365   -4.860171  1.034841
# 2018-07-02              11   0.722386   10.483319   -9.038548  1.026467
# 2018-07-03              34   2.870000   33.470043  -27.730042  1.008659
# 2020-07-13               1   0.064516    0.939061   -0.810028  1.034841
# 2020-07-14              15   1.028096   14.117203  -12.061011  1.033723
# 2020-07-16              78   6.595867   74.984500  -61.792766  1.022047
# 2020-09-21              78   9.904284   77.797194  -57.988626  1.001494
# 2019-02-19              67   7.917536   65.748729  -49.913656  1.010818
# 2019-03-03             272  24.721632  266.780128 -217.336864  1.010782
# 2019-06-12              24   1.821444   23.716120  -20.073231  1.006483
# 2019-12-20             116  13.377302  113.144166  -86.389563  1.014313
# 2020-11-04               7   0.451613    6.573426   -5.670200  1.034840
# 2019-12-19             192  19.601776  187.231096 -148.027544  1.014225
# 2020-04-16              93  10.343778   91.138156  -70.450600  1.011522
# 2020-04-02              56   6.838406   54.959232  -41.282419  1.010814
# 2020-05-26             113  14.031224  111.641207  -83.578760  1.006960
# 2020-07-09              69   7.321950   67.500811  -52.856911  1.012456
# 2020-07-09              95  10.983019   93.187723  -71.221684  1.011023
# 2020-10-16             179  20.158062  173.720239 -133.404115  1.017191
# 2020-12-08               3   0.193757    2.823356   -2.435842  1.033588
# 2020-08-03              99  10.952041   96.329625  -74.425543  1.015639
# 2020-08-03              54   6.848807   53.792142  -40.094529  1.002214
# 2020-12-08              50   3.227127   46.956739  -40.502485  1.034796
# 2020-10-22              45   5.694358   44.734904  -33.346188  1.003395
# 2020-10-25              16   1.037002   15.051921  -12.977917  1.033824
# 2020-12-09              16   1.173983   15.245644  -12.897679  1.026804
# 2020-09-14              58   6.116972   56.238945  -44.005002  1.017568
# 2021-02-01             101  11.357678  100.834937  -78.119582  1.000922
# 2021-01-20              74   8.832557   73.838286  -56.173171  1.001244
# 2021-03-25              59   6.824556   58.415342  -44.766230  1.005666
# 2021-02-23              67   8.229409   66.322904  -49.864086  1.005828
#
#             user_id
# date_time
# 2020-01-13      120
# 2018-07-02      130
# 2018-07-03      130
# 2020-07-13      268
# 2020-07-14      268
# 2020-07-16      268
# 2020-09-21      268
# 2019-02-19      305
# 2019-03-03      341
# 2019-06-12      395
# 2019-12-20      482
# 2020-11-04      522
# 2019-12-19      526
# 2020-04-16      560
# 2020-04-02      567
# 2020-05-26      635
# 2020-07-09      642
# 2020-07-09      643
# 2020-10-16      658
# 2020-12-08      663
# 2020-08-03      664
# 2020-08-03      674
# 2020-12-08      683
# 2020-10-22      694
# 2020-10-25      704
# 2020-12-09      707
# 2020-09-14      708
# 2021-02-01      750
# 2021-01-20      804
# 2021-03-25      843
# 2021-02-23      851

# %%
anomalies_active.sort_values(by='lb', ascending=True)
# Out:
#             pages_one_user    midband          ub          lb     pct_b  \
# date_time
# 2019-03-03             272  24.721632  266.780128 -217.336864  1.010782
# 2019-12-19             192  19.601776  187.231096 -148.027544  1.014225
# 2020-10-16             179  20.158062  173.720239 -133.404115  1.017191
# 2019-12-20             116  13.377302  113.144166  -86.389563  1.014313
# 2020-05-26             113  14.031224  111.641207  -83.578760  1.006960
# 2021-02-01             101  11.357678  100.834937  -78.119582  1.000922
# 2020-08-03              99  10.952041   96.329625  -74.425543  1.015639
# 2020-07-09              95  10.983019   93.187723  -71.221684  1.011023
# 2020-04-16              93  10.343778   91.138156  -70.450600  1.011522
# 2020-07-16              78   6.595867   74.984500  -61.792766  1.022047
# 2020-09-21              78   9.904284   77.797194  -57.988626  1.001494
# 2021-01-20              74   8.832557   73.838286  -56.173171  1.001244
# 2020-07-09              69   7.321950   67.500811  -52.856911  1.012456
# 2019-02-19              67   7.917536   65.748729  -49.913656  1.010818
# 2021-02-23              67   8.229409   66.322904  -49.864086  1.005828
# 2021-03-25              59   6.824556   58.415342  -44.766230  1.005666
# 2020-09-14              58   6.116972   56.238945  -44.005002  1.017568
# 2020-04-02              56   6.838406   54.959232  -41.282419  1.010814
# 2020-12-08              50   3.227127   46.956739  -40.502485  1.034796
# 2020-08-03              54   6.848807   53.792142  -40.094529  1.002214
# 2020-10-22              45   5.694358   44.734904  -33.346188  1.003395
# 2018-07-03              34   2.870000   33.470043  -27.730042  1.008659
# 2019-06-12              24   1.821444   23.716120  -20.073231  1.006483
# 2020-10-25              16   1.037002   15.051921  -12.977917  1.033824
# 2020-12-09              16   1.173983   15.245644  -12.897679  1.026804
# 2020-07-14              15   1.028096   14.117203  -12.061011  1.033723
# 2018-07-02              11   0.722386   10.483319   -9.038548  1.026467
# 2020-11-04               7   0.451613    6.573426   -5.670200  1.034840
# 2020-01-13               6   0.387097    5.634365   -4.860171  1.034841
# 2020-12-08               3   0.193757    2.823356   -2.435842  1.033588
# 2020-07-13               1   0.064516    0.939061   -0.810028  1.034841
#
#             user_id
# date_time
# 2019-03-03      341
# 2019-12-19      526
# 2020-10-16      658
# 2019-12-20      482
# 2020-05-26      635
# 2021-02-01      750
# 2020-08-03      664
# 2020-07-09      643
# 2020-04-16      560
# 2020-07-16      268
# 2020-09-21      268
# 2021-01-20      804
# 2020-07-09      642
# 2019-02-19      305
# 2021-02-23      851
# 2021-03-25      843
# 2020-09-14      708
# 2020-04-02      567
# 2020-12-08      683
# 2020-08-03      674
# 2020-10-22      694
# 2018-07-03      130
# 2019-06-12      395
# 2020-10-25      704
# 2020-12-09      707
# 2020-07-14      268
# 2018-07-02      130
# 2020-11-04      522
# 2020-01-13      120
# 2020-12-08      663
# 2020-07-13      268

# %%
df_341 = one_user_df_prep(df, 341)

# %%
df_341.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %%
df_526 = one_user_df_prep(df, 526)
df_526.plot(figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='date_time'>

# %% [markdown]
# # 6)  What topics are grads continuing to reference after graduation and into their jobs (for each program)?

# %%
# grads definded? after end_date
#

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff  active
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False   False
# 2018-01-26 09:56:02   Full-Stack PHP     False   False
# 2018-01-26 09:56:05   Full-Stack PHP     False   False
# 2018-01-26 09:56:06   Full-Stack PHP     False   False
# 2018-01-26 09:56:24  Full-Stack Java     False    True

# %%
df['is_grad'] = df.index > df.end_date

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff  active  is_grad
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:02   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:05   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:06   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:24  Full-Stack Java     False    True    False

# %%
df_grad = df[df.is_grad == True]
df_grad.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 10:14:47                                    /       11        1.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 10:14:47  97.105.19.61   Arches 2014-02-04 2014-04-22
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 10:14:47 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
#
#                             program  is_staff  active  is_grad
# date_time
# 2018-01-26 09:55:03  Full-Stack PHP     False   False     True
# 2018-01-26 09:56:02  Full-Stack PHP     False   False     True
# 2018-01-26 09:56:05  Full-Stack PHP     False   False     True
# 2018-01-26 09:56:06  Full-Stack PHP     False   False     True
# 2018-01-26 10:14:47  Full-Stack PHP     False   False     True

# %%
# What topics are they referenceing? main paths per program

# %%
df_grad = df_grad[df_grad['path'] != '/']
df_grad.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 10:14:51                         javascript-i       11        1.0
# 2018-01-26 10:15:02               javascript-i/functions       11        1.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 10:14:51  97.105.19.61   Arches 2014-02-04 2014-04-22
# 2018-01-26 10:15:02  97.105.19.61   Arches 2014-02-04 2014-04-22
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 10:14:51 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 10:15:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
#
#                             program  is_staff  active  is_grad
# date_time
# 2018-01-26 09:56:02  Full-Stack PHP     False   False     True
# 2018-01-26 09:56:05  Full-Stack PHP     False   False     True
# 2018-01-26 09:56:06  Full-Stack PHP     False   False     True
# 2018-01-26 10:14:51  Full-Stack PHP     False   False     True
# 2018-01-26 10:15:02  Full-Stack PHP     False   False     True

# %%
page_views_grad = df_grad[df_grad.name != 'Staff'].groupby(['program'])['path'].agg(['count', 'nunique'])
page_views_grad
# Out:
#                  count  nunique
# program
# Data Science     10098      436
# Front-End            4        3
# Full-Stack Java  67904      819
# Full-Stack PHP   28867      709

# %%
def biggest_lesson_grad(df_grad, program):
    df_grad = df_grad[df_grad.program == program]
    df_grad = df_grad.dropna()
    #df_new = df_new[df_new.name != 'Everglades']
    df_bigget_lesson_grad = df_grad.path.value_counts().idxmax()
    return df_bigget_lesson_grad

# %%
df_grad.path.value_counts()
# Out:
# javascript-i                         4969
# spring                               4273
# search/search_index.json             4183
# html-css                             3687
# java-iii                             3541
#                                      ...
# servlets                                1
# php                                     1
# 2.03.05_NormalityTests                  1
# interfaces-and-abstract-classes         1
# prework/fundamentals/if-statement       1
# Name: path, Length: 1864, dtype: int64

# %%
for i in list(df_grad.program.unique()):
    big_lesson_grad = biggest_lesson_grad(df_grad, i)
    print(big_lesson_grad, ' :', i)
    print('-----------------------------------')
    #programs_list.extend(df_new[df_new.name == i].program.unique())
    #lesson_list.append(big_lesson)
    #cohort_list.append(i)
# Out:
# index.html  : Full-Stack PHP
# -----------------------------------
# javascript-i  : Full-Stack Java
# -----------------------------------
# content/html-css  : Front-End
# -----------------------------------
# search/search_index.json  : Data Science
# -----------------------------------

# %% [markdown]
# # 3) is there any suspicous activity such as users accessing the curriculum who shouldnt be? Does it appear that any web_scraping is happening? are there any suspicous IP addresses?

# %%
df.head()
# Out:
#                                                     path  user_id  cohort_id  \
# date_time
# 2018-01-26 09:55:03                                    /        1        8.0
# 2018-01-26 09:56:02                              java-ii        1        8.0
# 2018-01-26 09:56:05  java-ii/object-oriented-programming        1        8.0
# 2018-01-26 09:56:06   slides/object_oriented_programming        1        8.0
# 2018-01-26 09:56:24            javascript-i/conditionals        2       22.0
#
#                                ip     name start_date   end_date  \
# date_time
# 2018-01-26 09:55:03  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:02  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:05  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:06  97.105.19.61  Hampton 2015-09-22 2016-02-06
# 2018-01-26 09:56:24  97.105.19.61    Teddy 2018-01-08 2018-05-17
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-01-26 09:55:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:02 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:05 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:06 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-01-26 09:56:24 2018-01-08 13:59:10 2018-01-08 13:59:10         2.0
#
#                              program  is_staff  active  is_grad
# date_time
# 2018-01-26 09:55:03   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:02   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:05   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:06   Full-Stack PHP     False   False     True
# 2018-01-26 09:56:24  Full-Stack Java     False    True    False

# %% [markdown]
# ### LEts look at users using dbscan for any anomalies

# %%
page_views_anomaly = df.groupby(['user_id'])['path'].agg(['count', 'nunique'])
page_views_anomaly
# Out:
#          count  nunique
# user_id
# 1         7404      976
# 2         1541      151
# 3         1562      169
# 4          692      143
# 5         1701      197
# ...        ...      ...
# 977         86       12
# 978         55       18
# 979        127       20
# 980          3        1
# 981         42        9
#
# [981 rows x 2 columns]

# %%
# create the scaler
scaler = MinMaxScaler().fit(page_views_anomaly)
# use the scaler
page_views__anomaly_scaled_array = scaler.transform(page_views_anomaly)
page_views__anomaly_scaled_array[0:10]
# Out:
# array([[0.41329835, 1.        ],
#        [0.08597588, 0.15384615],
#        [0.08714828, 0.17230769],
#        [0.03857749, 0.14564103],
#        [0.09490844, 0.20102564],
#        [0.07855069, 0.22974359],
#        [0.10060295, 0.17435897],
#        [0.02690933, 0.09128205],
#        [0.03260384, 0.14871795],
#        [0.05141804, 0.14666667]])

# %%
dbsc = DBSCAN(eps = 0.1, min_samples=4).fit(page_views__anomaly_scaled_array)

# %%
columns = list(page_views_anomaly.columns)
scaled_columns = ["scaled_" + column for column in columns]

# %%
scaled_df = pd.DataFrame(page_views__anomaly_scaled_array, columns=scaled_columns, index=page_views_anomaly.index)

# %%
# Merge the scaled and non-scaled values into one dataframe
page_views_anomaly = page_views_anomaly.merge(scaled_df, left_index=True, right_index=True)

# %%
labels = dbsc.labels_

# %%
#add labels back to the dataframe
page_views_anomaly['labels'] = labels

# how many unique labels (clusters) are created by DBSCAN?
page_views_anomaly.labels.value_counts()
# Out:
#  0    976
# -1      5
# Name: labels, dtype: int64

# %%
page_views_anomaly[page_views_anomaly.labels==-1]
# Out:
#          count  nunique  scaled_count  scaled_nunique  labels
# user_id
# 1         7404      976      0.413298        1.000000      -1
# 11       17913      871      1.000000        0.892308      -1
# 53       12329      333      0.688254        0.340513      -1
# 64       16347      437      0.912573        0.447179      -1
# 248       5075      625      0.283274        0.640000      -1

# %%
plt.scatter(page_views_anomaly['scaled_count'], page_views_anomaly['scaled_nunique'], c=page_views_anomaly.labels)
plt.show()

# %% [markdown]
# ### Now lets look at the ip using dbscan to see any anomalies

# %%
page_views_ip = df.groupby(['ip', 'user_id'])['path'].agg(['count', 'nunique'])
page_views_ip
# Out:
#                          count  nunique
# ip              user_id
# 100.11.170.135  658        114       20
# 100.19.73.35    658        408       57
# 100.35.67.162   52          11        8
# 103.137.12.164  469          9        8
# 103.208.220.130 369          1        1
# ...                        ...      ...
# 99.97.210.12    606         18       12
# 99.98.245.245   618          2        2
# 99.98.32.165    324        267      101
# 99.98.32.97     481         46       23
# 99.98.36.168    310        391      164
#
# [7535 rows x 2 columns]

# %%
# create the scaler
scaler = MinMaxScaler().fit(page_views_ip)
# use the scaler
page_views_ip_scaled_array = scaler.transform(page_views_ip)
#######
dbsc = DBSCAN(eps = 0.1, min_samples=4).fit(page_views_ip_scaled_array)

columns = list(page_views_ip.columns)
scaled_columns = ["scaled_" + column for column in columns]

scaled_df = pd.DataFrame(page_views_ip_scaled_array, columns=scaled_columns, index=page_views_ip.index)


# Merge the scaled and non-scaled values into one dataframe
page_views_ip = page_views_ip.merge(scaled_df, left_index=True, right_index=True)

labels = dbsc.labels_

#add labels back to the dataframe
page_views_ip['labels'] = labels

# how many unique labels (clusters) are created by DBSCAN?
page_views_ip.labels.value_counts()
# Out:
#  0    7526
# -1       9
# Name: labels, dtype: int64

# %%
page_views_ip[page_views_ip.labels==-1]
# Out:
#                         count  nunique  scaled_count  scaled_nunique  labels
# ip             user_id
# 71.150.217.33  64        6790      290      0.963252        0.479270      -1
# 76.185.131.226 11        2618      436      0.371311        0.721393      -1
# 76.185.145.231 11        4754      336      0.674376        0.555556      -1
# 97.105.19.58   1         3099      604      0.439557        1.000000      -1
#                11        7049      590      1.000000        0.976783      -1
#                53        4895      224      0.694381        0.369818      -1
#                64        5690      250      0.807179        0.412935      -1
#                248       2231      415      0.316402        0.686567      -1
#                404       1293      306      0.183314        0.505804      -1

# %%
plt.scatter(page_views_ip['scaled_count'], page_views_ip['scaled_nunique'], c=page_views_ip.labels)
plt.show()

# %%
df[df.user_id == 404]
# Out:
#                                                                   path  \
# date_time
# 2019-05-09 10:45:33                                                  /
# 2019-05-09 11:02:41                         ada-python-assessment.html
# 2019-05-09 14:14:02                                                git
# 2019-05-09 14:49:48                                                git
# 2019-05-09 15:04:36                                          open_data
# ...                                                                ...
# 2019-11-25 15:51:02                                                  /
# 2019-11-25 15:51:06                    10-anomaly-detection/1-overview
# 2019-11-25 15:51:06  10-anomaly-detection/AnomalyDetectionCartoon.jpeg
# 2019-11-25 15:51:10                     13-advanced-topics/1-tidy-data
# 2019-11-25 15:51:48              13-advanced-topics/2-cross-validation
#
#                      user_id  cohort_id            ip   name start_date  \
# date_time
# 2019-05-09 10:45:33      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-05-09 11:02:41      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-05-09 14:14:02      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-05-09 14:49:48      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-05-09 15:04:36      404       28.0  97.105.19.58  Staff 2014-02-04
# ...                      ...        ...           ...    ...        ...
# 2019-11-25 15:51:02      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-11-25 15:51:06      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-11-25 15:51:06      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-11-25 15:51:10      404       28.0  97.105.19.58  Staff 2014-02-04
# 2019-11-25 15:51:48      404       28.0  97.105.19.58  Staff 2014-02-04
#
#                       end_date          created_at          updated_at  \
# date_time
# 2019-05-09 10:45:33 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-05-09 11:02:41 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-05-09 14:14:02 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-05-09 14:49:48 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-05-09 15:04:36 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# ...                        ...                 ...                 ...
# 2019-11-25 15:51:02 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-11-25 15:51:06 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-11-25 15:51:06 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-11-25 15:51:10 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2019-11-25 15:51:48 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
#
#                      program_id          program  is_staff  active  is_grad
# date_time
# 2019-05-09 10:45:33         2.0  Full-Stack Java     False   False     True
# 2019-05-09 11:02:41         2.0  Full-Stack Java     False   False     True
# 2019-05-09 14:14:02         2.0  Full-Stack Java     False   False     True
# 2019-05-09 14:49:48         2.0  Full-Stack Java     False   False     True
# 2019-05-09 15:04:36         2.0  Full-Stack Java     False   False     True
# ...                         ...              ...       ...     ...      ...
# 2019-11-25 15:51:02         2.0  Full-Stack Java     False   False     True
# 2019-11-25 15:51:06         2.0  Full-Stack Java     False   False     True
# 2019-11-25 15:51:06         2.0  Full-Stack Java     False   False     True
# 2019-11-25 15:51:10         2.0  Full-Stack Java     False   False     True
# 2019-11-25 15:51:48         2.0  Full-Stack Java     False   False     True
#
# [1668 rows x 14 columns]

# %%
df[df.user_id == 11]
# Out:
#                                                                   path  \
# date_time
# 2018-01-26 10:14:47                                                  /
# 2018-01-26 10:14:51                                       javascript-i
# 2018-01-26 10:15:02                             javascript-i/functions
# 2018-01-26 11:46:29  appendix/further-reading/javascript/hoisting.html
# 2018-01-26 11:46:39                                           appendix
# ...                                                                ...
# 2021-04-21 14:21:05  fundamentals/diagram-of-ds-pipeline-fraud-exam...
# 2021-04-21 14:21:05          fundamentals/ml-methodologies-drawing.jpg
# 2021-04-21 14:21:05             fundamentals/modern-data-scientist.jpg
# 2021-04-21 14:21:05                 fundamentals/AI-ML-DL-timeline.jpg
# 2021-04-21 14:21:08                     fundamentals/environment-setup
#
#                      user_id  cohort_id              ip    name start_date  \
# date_time
# 2018-01-26 10:14:47       11        1.0    97.105.19.61  Arches 2014-02-04
# 2018-01-26 10:14:51       11        1.0    97.105.19.61  Arches 2014-02-04
# 2018-01-26 10:15:02       11        1.0    97.105.19.61  Arches 2014-02-04
# 2018-01-26 11:46:29       11        1.0    97.105.19.61  Arches 2014-02-04
# 2018-01-26 11:46:39       11        1.0    97.105.19.61  Arches 2014-02-04
# ...                      ...        ...             ...     ...        ...
# 2021-04-21 14:21:05       11       28.0  76.185.131.226   Staff 2014-02-04
# 2021-04-21 14:21:05       11       28.0  76.185.131.226   Staff 2014-02-04
# 2021-04-21 14:21:05       11       28.0  76.185.131.226   Staff 2014-02-04
# 2021-04-21 14:21:05       11       28.0  76.185.131.226   Staff 2014-02-04
# 2021-04-21 14:21:08       11       28.0  76.185.131.226   Staff 2014-02-04
#
#                       end_date          created_at          updated_at  \
# date_time
# 2018-01-26 10:14:47 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 2018-01-26 10:14:51 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 2018-01-26 10:15:02 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 2018-01-26 11:46:29 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# 2018-01-26 11:46:39 2014-04-22 2016-06-14 19:52:26 2016-06-14 19:52:26
# ...                        ...                 ...                 ...
# 2021-04-21 14:21:05 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2021-04-21 14:21:05 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2021-04-21 14:21:05 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2021-04-21 14:21:05 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
# 2021-04-21 14:21:08 2014-02-04 2018-12-06 17:04:19 2018-12-06 17:04:19
#
#                      program_id          program  is_staff  active  is_grad
# date_time
# 2018-01-26 10:14:47         1.0   Full-Stack PHP     False   False     True
# 2018-01-26 10:14:51         1.0   Full-Stack PHP     False   False     True
# 2018-01-26 10:15:02         1.0   Full-Stack PHP     False   False     True
# 2018-01-26 11:46:29         1.0   Full-Stack PHP     False   False     True
# 2018-01-26 11:46:39         1.0   Full-Stack PHP     False   False     True
# ...                         ...              ...       ...     ...      ...
# 2021-04-21 14:21:05         2.0  Full-Stack Java     False   False     True
# 2021-04-21 14:21:05         2.0  Full-Stack Java     False   False     True
# 2021-04-21 14:21:05         2.0  Full-Stack Java     False   False     True
# 2021-04-21 14:21:05         2.0  Full-Stack Java     False   False     True
# 2021-04-21 14:21:08         2.0  Full-Stack Java     False   False     True
#
# [17913 rows x 14 columns]

# %%
df[df.user_id == 248]
# Out:
#                                                        path  user_id  \
# date_time
# 2018-09-05 14:28:23                                       /      248
# 2018-09-07 14:53:23                                       /      248
# 2018-09-07 14:54:13                                html-css      248
# 2018-09-07 14:56:07                   html-css/introduction      248
# 2018-09-07 14:57:00                       html-css/elements      248
# ...                                                     ...      ...
# 2021-04-20 10:02:09  fundamentals/modern-data-scientist.jpg      248
# 2021-04-20 10:02:10      fundamentals/AI-ML-DL-timeline.jpg      248
# 2021-04-20 10:02:14                      sql/mysql-overview      248
# 2021-04-20 10:02:23                       python/dataframes      248
# 2021-04-21 09:59:30              python/advanced-dataframes      248
#
#                      cohort_id               ip    name start_date   end_date  \
# date_time
# 2018-09-05 14:28:23        1.0     97.105.19.58  Arches 2014-02-04 2014-04-22
# 2018-09-07 14:53:23        1.0     97.105.19.58  Arches 2014-02-04 2014-04-22
# 2018-09-07 14:54:13        1.0     97.105.19.58  Arches 2014-02-04 2014-04-22
# 2018-09-07 14:56:07        1.0     97.105.19.58  Arches 2014-02-04 2014-04-22
# 2018-09-07 14:57:00        1.0     97.105.19.58  Arches 2014-02-04 2014-04-22
# ...                        ...              ...     ...        ...        ...
# 2021-04-20 10:02:09       28.0  173.173.115.201   Staff 2014-02-04 2014-02-04
# 2021-04-20 10:02:10       28.0  173.173.115.201   Staff 2014-02-04 2014-02-04
# 2021-04-20 10:02:14       28.0  173.173.115.201   Staff 2014-02-04 2014-02-04
# 2021-04-20 10:02:23       28.0  173.173.115.201   Staff 2014-02-04 2014-02-04
# 2021-04-21 09:59:30       28.0  173.173.115.201   Staff 2014-02-04 2014-02-04
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-09-05 14:28:23 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-09-07 14:53:23 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-09-07 14:54:13 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-09-07 14:56:07 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-09-07 14:57:00 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# ...                                 ...                 ...         ...
# 2021-04-20 10:02:09 2018-12-06 17:04:19 2018-12-06 17:04:19         2.0
# 2021-04-20 10:02:10 2018-12-06 17:04:19 2018-12-06 17:04:19         2.0
# 2021-04-20 10:02:14 2018-12-06 17:04:19 2018-12-06 17:04:19         2.0
# 2021-04-20 10:02:23 2018-12-06 17:04:19 2018-12-06 17:04:19         2.0
# 2021-04-21 09:59:30 2018-12-06 17:04:19 2018-12-06 17:04:19         2.0
#
#                              program  is_staff  active  is_grad
# date_time
# 2018-09-05 14:28:23   Full-Stack PHP     False   False     True
# 2018-09-07 14:53:23   Full-Stack PHP     False   False     True
# 2018-09-07 14:54:13   Full-Stack PHP     False   False     True
# 2018-09-07 14:56:07   Full-Stack PHP     False   False     True
# 2018-09-07 14:57:00   Full-Stack PHP     False   False     True
# ...                              ...       ...     ...      ...
# 2021-04-20 10:02:09  Full-Stack Java     False   False     True
# 2021-04-20 10:02:10  Full-Stack Java     False   False     True
# 2021-04-20 10:02:14  Full-Stack Java     False   False     True
# 2021-04-20 10:02:23  Full-Stack Java     False   False     True
# 2021-04-21 09:59:30  Full-Stack Java     False   False     True
#
# [5075 rows x 14 columns]

# %%
df[df.ip == '97.105.19.58']
# Out:
#                                                 path  user_id  cohort_id  \
# date_time
# 2018-07-16 07:51:57           javascript-ii/promises      211        1.0
# 2018-07-16 07:58:03  javascript-ii/map-filter-reduce      211        1.0
# 2018-07-16 07:59:50           javascript-ii/promises      211        1.0
# 2018-07-16 08:07:37                       index.html       53       14.0
# 2018-07-16 08:07:41                    javascript-ii       53       14.0
# ...                                              ...      ...        ...
# 2020-03-23 15:10:09                              toc      625       57.0
# 2020-03-23 15:10:18                              toc      623       57.0
# 2020-03-23 15:20:39                                /      627       57.0
# 2020-03-23 15:24:54                                /      628       57.0
# 2020-03-23 16:07:31                                /      629       57.0
#
#                                ip      name start_date   end_date  \
# date_time
# 2018-07-16 07:51:57  97.105.19.58    Arches 2014-02-04 2014-04-22
# 2018-07-16 07:58:03  97.105.19.58    Arches 2014-02-04 2014-04-22
# 2018-07-16 07:59:50  97.105.19.58    Arches 2014-02-04 2014-04-22
# 2018-07-16 08:07:37  97.105.19.58    Lassen 2016-07-18 2016-11-10
# 2018-07-16 08:07:41  97.105.19.58    Lassen 2016-07-18 2016-11-10
# ...                           ...       ...        ...        ...
# 2020-03-23 15:10:09  97.105.19.58  Ganymede 2020-03-23 2020-08-20
# 2020-03-23 15:10:18  97.105.19.58  Ganymede 2020-03-23 2020-08-20
# 2020-03-23 15:20:39  97.105.19.58  Ganymede 2020-03-23 2020-08-20
# 2020-03-23 15:24:54  97.105.19.58  Ganymede 2020-03-23 2020-08-20
# 2020-03-23 16:07:31  97.105.19.58  Ganymede 2020-03-23 2020-08-20
#
#                              created_at          updated_at  program_id  \
# date_time
# 2018-07-16 07:51:57 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-07-16 07:58:03 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-07-16 07:59:50 2016-06-14 19:52:26 2016-06-14 19:52:26         1.0
# 2018-07-16 08:07:37 2016-07-18 19:06:27 2016-07-18 19:06:27         1.0
# 2018-07-16 08:07:41 2016-07-18 19:06:27 2016-07-18 19:06:27         1.0
# ...                                 ...                 ...         ...
# 2020-03-23 15:10:09 2020-03-23 17:52:16 2020-03-23 17:52:16         2.0
# 2020-03-23 15:10:18 2020-03-23 17:52:16 2020-03-23 17:52:16         2.0
# 2020-03-23 15:20:39 2020-03-23 17:52:16 2020-03-23 17:52:16         2.0
# 2020-03-23 15:24:54 2020-03-23 17:52:16 2020-03-23 17:52:16         2.0
# 2020-03-23 16:07:31 2020-03-23 17:52:16 2020-03-23 17:52:16         2.0
#
#                              program  is_staff  active  is_grad
# date_time
# 2018-07-16 07:51:57   Full-Stack PHP     False   False     True
# 2018-07-16 07:58:03   Full-Stack PHP     False   False     True
# 2018-07-16 07:59:50   Full-Stack PHP     False   False     True
# 2018-07-16 08:07:37   Full-Stack PHP     False   False     True
# 2018-07-16 08:07:41   Full-Stack PHP     False   False     True
# ...                              ...       ...     ...      ...
# 2020-03-23 15:10:09  Full-Stack Java     False    True    False
# 2020-03-23 15:10:18  Full-Stack Java     False    True    False
# 2020-03-23 15:20:39  Full-Stack Java     False    True    False
# 2020-03-23 15:24:54  Full-Stack Java     False    True    False
# 2020-03-23 16:07:31  Full-Stack Java     False    True    False
#
# [284579 rows x 14 columns]
